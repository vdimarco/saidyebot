# %%
from slackclient import SlackClient

token = "xoxb-48268747110-YqfOdmsSrt7Fg7ZgAKhS8BEL" #andrewbot
#token = "xoxb-48229673667-O2UeLMKPQLY9ylFhtKMVLPif" #vonalytics
sc = SlackClient(token)

im_list = sc.api_call('im.list')

for im in im_list['ims']:
    print im
# Out:
# {u'created': 1465113919, u'is_user_deleted': False, u'is_org_shared': False, u'user': u'USLACKBOT', u'is_im': True, u'id': u'D1E7U8G8L'}
# {u'created': 1465113919, u'is_user_deleted': False, u'is_org_shared': False, u'user': u'U106EL2BS', u'is_im': True, u'id': u'D1E80N4SU'}
# {u'created': 1465113919, u'is_user_deleted': False, u'is_org_shared': False, u'user': u'U10A2E74G', u'is_im': True, u'id': u'D1E84LCCV'}
# {u'created': 1465113919, u'is_user_deleted': False, u'is_org_shared': False, u'user': u'U10C5KCGJ', u'is_im': True, u'id': u'D1E8FG16W'}
# {u'created': 1465113919, u'is_user_deleted': False, u'is_org_shared': False, u'user': u'U10N0JRSP', u'is_im': True, u'id': u'D1E7WMZC6'}

# %%
print sc.api_call('users.list')
# Out:
# {u'cache_ts': 1465126293, u'ok': True, u'members': [{u'status': None, u'profile': {u'first_name': u'Andrew', u'last_name': u'The Incredible', u'real_name': u'Andrew The Incredible', u'image_24': u'https://secure.gravatar.com/avatar/9d7406c0a9800e826725cc7db838d95c.jpg?s=24&d=https%3A%2F%2Fa.slack-edge.com%2F66f9%2Fimg%2Favatars%2Fava_0002-24.png', u'real_name_normalized': u'Andrew The Incredible', u'image_512': u'https://secure.gravatar.com/avatar/9d7406c0a9800e826725cc7db838d95c.jpg?s=512&d=https%3A%2F%2Fa.slack-edge.com%2F7fa9%2Fimg%2Favatars%2Fava_0002-512.png', u'image_32': u'https://secure.gravatar.com/avatar/9d7406c0a9800e826725cc7db838d95c.jpg?s=32&d=https%3A%2F%2Fa.slack-edge.com%2F0180%2Fimg%2Favatars%2Fava_0002-32.png', u'image_48': u'https://secure.gravatar.com/avatar/9d7406c0a9800e826725cc7db838d95c.jpg?s=48&d=https%3A%2F%2Fa.slack-edge.com%2F66f9%2Fimg%2Favatars%2Fava_0002-48.png', u'image_72': u'https://secure.gravatar.com/avatar/9d7406c0a9800e826725cc7db838d95c.jpg?s=7
# ...
