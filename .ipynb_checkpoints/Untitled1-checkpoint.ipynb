# %%
from slackclient import SlackClient

token = "xoxb-48268747110-YqfOdmsSrt7Fg7ZgAKhS8BEL" #andrewbot
#token = "xoxb-48229673667-O2UeLMKPQLY9ylFhtKMVLPif" #vonalytics
sc = SlackClient(token)

# %%
print sc.api_call("api.test")
print sc.api_call("channels.info", channel="1234567890")
print sc.api_call(
    "chat.postMessage", channel="#general", text="Hello from Python! :tada:",
    username='pybot', icon_emoji=':robot_face:'
)
# Out:
# {u'args': {u'token': u'xoxb-48268747110-YqfOdmsSrt7Fg7ZgAKhS8BEL'}, u'ok': True}
# {u'ok': False, u'error': u'channel_not_found'}
# {u'message': {u'username': u'pybot', u'icons': {u'image_64': u'https://slack.global.ssl.fastly.net/d4bf/img/emoji_2015_2/apple/1f916.png', u'emoji': u':robot_face:'}, u'text': u'Hello from Python! :tada:', u'ts': u'1465118475.000003', u'subtype': u'bot_message', u'type': u'message', u'bot_id': u'B1E89N6DP'}, u'ok': True, u'ts': u'1465118475.000003', u'channel': u'C106M6YKT'}

# %%
user_list = sc.api_call("users.list")['members']

# %%
for user in user_list:
    id = user['id'] 
    user_profile = user['profile']
    print "%s %s" % (id, user_profile['first_name'])
# Out:
# U106EL2BS Andrew
# U10A2E74G Fred
# U10N0JRSP Guillaume
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-cd6f727d440e> in <module>()
#       2     id = user['id']
#       3     user_profile = user['profile']
# ----> 4     print "%s %s" % (id, user_profile['first_name'])
#       5
#
# KeyError: 'first_name'

# %%
user_list
# Out:
# [{u'color': u'9f69e7',
#   u'deleted': False,
#   u'has_2fa': False,
#   u'id': u'U106EL2BS',
#   u'is_admin': True,
#   u'is_bot': False,
#   u'is_owner': True,
#   u'is_primary_owner': True,
#   u'is_restricted': False,
#   u'is_ultra_restricted': False,
#   u'name': u'andrew',
#   u'profile': {u'avatar_hash': u'g9d7406c0a98',
#    u'email': u'andrew@makeitbloom.com',
#    u'first_name': u'Andrew',
#    u'image_192': u'https://secure.gravatar.com/avatar/9d7406c0a9800e826725cc7db838d95c.jpg?s=192&d=https%3A%2F%2Fa.slack-edge.com%2F7fa9%2Fimg%2Favatars%2Fava_0002-192.png',
#    u'image_24': u'https://secure.gravatar.com/avatar/9d7406c0a9800e826725cc7db838d95c.jpg?s=24&d=https%3A%2F%2Fa.slack-edge.com%2F66f9%2Fimg%2Favatars%2Fava_0002-24.png',
#    u'image_32': u'https://secure.gravatar.com/avatar/9d7406c0a9800e826725cc7db838d95c.jpg?s=32&d=https%3A%2F%2Fa.slack-edge.com%2F0180%2Fimg%2Favatars%2Fava_0002-32.png',
#    u'image_48': u'https://secure.gravatar.com/avatar/9d7406c0a9800e826725cc7db838d95c.jpg?s=48&d=https%3A%2F%2Fa.slack-edge.com%2F66f9%2Fimg%2Favatars%2Fava_0002-48.png',
#    u'image_512': u'https://secure.gravatar.com/avatar/9d7406c0a9800e826725cc7db838d95c.jpg?s=512&d=https%3A%2F%2Fa.slack-edge.com%2F7fa9%2Fimg%2Favatars%2Fava_0002-512.png',
#    u'image_72': u'https://secure.gravatar.com/avatar/9d7406c0a9800e826725cc7db838d95c.jpg?s=72&d=https%3A%2F%2Fa.slack-edge.com%2F66f9%2Fimg%2Favatars%2Fava_0002-72.png',
#    u'last_name': u'The Incredible',
#    u'real_name': u'Andrew The Incredible',
#    u'real_name_normalized': u'Andrew The Incredible'},
#   u'real_name': u'Andrew The Incredible',
#   u'status': None,
#   u'team_id': u'T106M6YDP',
#   u'tz': u'America/Indiana/Indianapolis',
#   u'tz_label': u'Eastern Daylight Time',
#   u'tz_offset': -14400},
#  {u'color': u'e7392d',
#   u'deleted': False,
#   u'has_2fa': False,
#   u'id': u'U10A2E74G',
#   u'is_admin': False,
#   u'is_bot': False,
#   u'is_owner': False,
#   u'is_primary_owner': False,
#   u'is_restricted': False,
#   u'is_ultra_restricted': False,
#   u'name': u'fred',
#   u'profile': {u'avatar_hash': u'gc24b7410636',
#    u'email': u'fred@makeitbloom.com',
#    u'first_name': u'Fred',
#    u'image_192': u'https://secure.gravatar.com/avatar/c24b741063699d86492a5bf4587d3233.jpg?s=192&d=https%3A%2F%2Fa.slack-edge.com%2F7fa9%2Fimg%2Favatars%2Fava_0014-192.png',
#    u'image_24': u'https://secure.gravatar.com/avatar/c24b741063699d86492a5bf4587d3233.jpg?s=24&d=https%3A%2F%2Fa.slack-edge.com%2F66f9%2Fimg%2Favatars%2Fava_0014-24.png',
#    u'image_32': u'https://secure.gravatar.com/avatar/c24b741063699d86492a5bf4587d3233.jpg?s=32&d=https%3A%2F%2Fa.slack-edge.com%2F66f9%2Fimg%2Favatars%2Fava_0014-32.png',
#    u'image_48': u'https://secure.gravatar.com/avatar/c24b741063699d86492a5bf4587d3233.jpg?s=48&d=https%3A%2F%2Fa.slack-edge.com%2F66f9%2Fimg%2Favatars%2Fava_0014-48.png',
#    u'image_512': u'https://secure.gravatar.com/avatar/c24b741063699d86492a5bf4587d3233.jpg?s=512&d=https%3A%2F%2Fa.slack-edge.com%2F7fa9%2Fimg%2Favatars%2Fava_0014-512.png',
#    u'image_72': u'https://secure.gravatar.com/avatar/c24b741063699d86492a5bf4587d3233.jpg?s=72&d=https%3A%2F%2Fa.slack-edge.com%2F66f9%2Fimg%2Favatars%2Fava_0014-72.png',
#    u'last_name': u'The Great',
#    u'real_name': u'Fred The Great',
#    u'real_name_normalized': u'Fred The Great'},
#   u'real_name': u'Fred The Great',
#   u'status': None,
#   u'team_id': u'T106M6YDP',
#   u'tz': u'America/Indiana/Indianapolis',
#   u'tz_label': u'Eastern Daylight Time',
#   u'tz_offset': -14400},
#  {u'color': u'674b1b',
#   u'deleted': False,
#   u'has_2fa': False,
#   u'id': u'U10N0JRSP',
#   u'is_admin': False,
#   u'is_bot': False,
#   u'is_owner': False,
#   u'is_primary_owner': False,
#   u'is_restricted': False,
#   u'is_ultra_restricted': False,
#   u'name': u'guilaj91',
#   u'profile': {u'avatar_hash': u'g048f7a74987',
#    u'email': u'lajoieguillaume91@gmail.com',
#    u'first_name': u'Guillaume',
#    u'image_192': u'https://secure.gravatar.com/avatar/048f7a74987c0beabc78141e5b9e2691.jpg?s=192&d=https%3A%2F%2Fa.slack-edge.com%2F7fa9%2Fimg%2Favatars%2Fava_0005-192.png',
#    u'image_24': u'https://secure.gravatar.com/avatar/048f7a74987c0beabc78141e5b9e2691.jpg?s=24&d=https%3A%2F%2Fa.slack-edge.com%2F66f9%2Fimg%2Favatars%2Fava_0005-24.png',
#    u'image_32': u'https://secure.gravatar.com/avatar/048f7a74987c0beabc78141e5b9e2691.jpg?s=32&d=https%3A%2F%2Fa.slack-edge.com%2F66f9%2Fimg%2Favatars%2Fava_0005-32.png',
#    u'image_48': u'https://secure.gravatar.com/avatar/048f7a74987c0beabc78141e5b9e2691.jpg?s=48&d=https%3A%2F%2Fa.slack-edge.com%2F66f9%2Fimg%2Favatars%2Fava_0005-48.png',
#    u'image_512': u'https://secure.gravatar.com/avatar/048f7a74987c0beabc78141e5b9e2691.jpg?s=512&d=https%3A%2F%2Fa.slack-edge.com%2F7fa9%2Fimg%2Favatars%2Fava_0005-512.png',
#    u'image_72': u'https://secure.gravatar.com/avatar/048f7a74987c0beabc78141e5b9e2691.jpg?s=72&d=https%3A%2F%2Fa.slack-edge.com%2F66f9%2Fimg%2Favatars%2Fava_0005-72.png',
#    u'last_name': u'The Wise',
#    u'real_name': u'Guillaume The Wise',
#    u'real_name_normalized': u'Guillaume The Wise'},
#   u'real_name': u'Guillaume The Wise',
#   u'status': None,
#   u'team_id': u'T106M6YDP',
#   u'tz': u'America/Indiana/Indianapolis',
#   u'tz_label': u'Eastern Daylight Time',
#   u'tz_offset': -14400},
#  {u'color': u'e96699',
#   u'deleted': False,
#   u'id': u'U118SPRU2',
#   u'is_admin': False,
#   u'is_bot': True,
#   u'is_owner': False,
#   u'is_primary_owner': False,
#   u'is_restricted': False,
#   u'is_ultra_restricted': False,
#   u'name': u'norrisbot',
#   u'profile': {u'api_app_id': u'',
#    u'avatar_hash': u'4dfefca853ff',
#    u'bot_id': u'B11887TEJ',
#    u'image_1024': u'https://avatars.slack-edge.com/2016-04-16/35298809746_4dfefca853ff78efe862_512.png',
#    u'image_192': u'https://avatars.slack-edge.com/2016-04-16/35298809746_4dfefca853ff78efe862_192.png',
#    u'image_24': u'https://avatars.slack-edge.com/2016-04-16/35298809746_4dfefca853ff78efe862_24.png',
#    u'image_32': u'https://avatars.slack-edge.com/2016-04-16/35298809746_4dfefca853ff78efe862_32.png',
#    u'image_48': u'https://avatars.slack-edge.com/2016-04-16/35298809746_4dfefca853ff78efe862_48.png',
#    u'image_512': u'https://avatars.slack-edge.com/2016-04-16/35298809746_4dfefca853ff78efe862_512.png',
#    u'image_72': u'https://avatars.slack-edge.com/2016-04-16/35298809746_4dfefca853ff78efe862_72.png',
#    u'image_original': u'https://avatars.slack-edge.com/2016-04-16/35298809746_4dfefca853ff78efe862_original.png',
#    u'real_name': u'',
#    u'real_name_normalized': u''},
#   u'real_name': u'',
#   u'status': None,
#   u'team_id': u'T106M6YDP',
#   u'tz': None,
#   u'tz_label': u'Pacific Daylight Time',
#   u'tz_offset': -25200},
#  {u'color': u'5b89d5',
#   u'deleted': False,
#   u'id': u'U1E710NB1',
#   u'is_admin': False,
#   u'is_bot': True,
#   u'is_owner': False,
#   u'is_primary_owner': False,
#   u'is_restricted': False,
#   u'is_ultra_restricted': False,
#   u'name': u'plork',
#   u'profile': {u'api_app_id': u'',
#    u'avatar_hash': u'314d3441f5b4',
#    u'bot_id': u'B1E710NA3',
#    u'image_1024': u'https://avatars.slack-edge.com/2016-06-04/48250051378_314d3441f5b43dd2cc13_512.png',
#    u'image_192': u'https://avatars.slack-edge.com/2016-06-04/48250051378_314d3441f5b43dd2cc13_192.png',
#    u'image_24': u'https://avatars.slack-edge.com/2016-06-04/48250051378_314d3441f5b43dd2cc13_24.png',
#    u'image_32': u'https://avatars.slack-edge.com/2016-06-04/48250051378_314d3441f5b43dd2cc13_32.png',
#    u'image_48': u'https://avatars.slack-edge.com/2016-06-04/48250051378_314d3441f5b43dd2cc13_48.png',
#    u'image_512': u'https://avatars.slack-edge.com/2016-06-04/48250051378_314d3441f5b43dd2cc13_512.png',
#    u'image_72': u'https://avatars.slack-edge.com/2016-06-04/48250051378_314d3441f5b43dd2cc13_72.png',
#    u'image_original': u'https://avatars.slack-edge.com/2016-06-04/48250051378_314d3441f5b43dd2cc13_original.png',
#    u'real_name': u'',
#    u'real_name_normalized': u''},
#   u'real_name': u'',
#   u'status': None,
#   u'team_id': u'T106M6YDP',
#   u'tz': None,
#   u'tz_label': u'Pacific Daylight Time',
#   u'tz_offset': -25200},
#  {u'color': u'3c989f',
#   u'deleted': False,
#   u'has_2fa': False,
#   u'id': u'U10C5KCGJ',
#   u'is_admin': False,
#   u'is_bot': False,
#   u'is_owner': False,
#   u'is_primary_owner': False,
#   u'is_restricted': False,
#   u'is_ultra_restricted': False,
#   u'name': u'queendrey',
#   u'profile': {u'avatar_hash': u'g06342c86bcf',
#    u'email': u'audrey@makeitbloom.com',
#    u'first_name': u'Audrey',
#    u'image_192': u'https://secure.gravatar.com/avatar/06342c86bcf91d1dc370db37b5693cb9.jpg?s=192&d=https%3A%2F%2Fa.slack-edge.com%2F7fa9%2Fimg%2Favatars%2Fava_0005-192.png',
#    u'image_24': u'https://secure.gravatar.com/avatar/06342c86bcf91d1dc370db37b5693cb9.jpg?s=24&d=https%3A%2F%2Fa.slack-edge.com%2F66f9%2Fimg%2Favatars%2Fava_0005-24.png',
#    u'image_32': u'https://secure.gravatar.com/avatar/06342c86bcf91d1dc370db37b5693cb9.jpg?s=32&d=https%3A%2F%2Fa.slack-edge.com%2F66f9%2Fimg%2Favatars%2Fava_0005-32.png',
#    u'image_48': u'https://secure.gravatar.com/avatar/06342c86bcf91d1dc370db37b5693cb9.jpg?s=48&d=https%3A%2F%2Fa.slack-edge.com%2F66f9%2Fimg%2Favatars%2Fava_0005-48.png',
#    u'image_512': u'https://secure.gravatar.com/avatar/06342c86bcf91d1dc370db37b5693cb9.jpg?s=512&d=https%3A%2F%2Fa.slack-edge.com%2F7fa9%2Fimg%2Favatars%2Fava_0005-512.png',
#    u'image_72': u'https://secure.gravatar.com/avatar/06342c86bcf91d1dc370db37b5693cb9.jpg?s=72&d=https%3A%2F%2Fa.slack-edge.com%2F66f9%2Fimg%2Favatars%2Fava_0005-72.png',
#    u'last_name': u'The Queen',
#    u'real_name': u'Audrey The Queen',
#    u'real_name_normalized': u'Audrey The Queen'},
#   u'real_name': u'Audrey The Queen',
#   u'status': None,
#   u'team_id': u'T106M6YDP',
#   u'tz': u'America/Indiana/Indianapolis',
#   u'tz_label': u'Eastern Daylight Time',
#   u'tz_offset': -14400},
#  {u'color': u'e0a729',
#   u'deleted': False,
#   u'id': u'U1E767MNV',
#   u'is_admin': False,
#   u'is_bot': True,
#   u'is_owner': False,
#   u'is_primary_owner': False,
#   u'is_restricted': False,
#   u'is_ultra_restricted': False,
#   u'name': u'testbot',
#   u'profile': {u'api_app_id': u'',
#    u'avatar_hash': u'48ecee52f8ee',
#    u'bot_id': u'B1E6X7AF2',
#    u'image_1024': u'https://avatars.slack-edge.com/2016-06-04/48244260161_48ecee52f8ee1efdc37c_512.png',
#    u'image_192': u'https://avatars.slack-edge.com/2016-06-04/48244260161_48ecee52f8ee1efdc37c_192.png',
#    u'image_24': u'https://avatars.slack-edge.com/2016-06-04/48244260161_48ecee52f8ee1efdc37c_24.png',
#    u'image_32': u'https://avatars.slack-edge.com/2016-06-04/48244260161_48ecee52f8ee1efdc37c_32.png',
#    u'image_48': u'https://avatars.slack-edge.com/2016-06-04/48244260161_48ecee52f8ee1efdc37c_48.png',
#    u'image_512': u'https://avatars.slack-edge.com/2016-06-04/48244260161_48ecee52f8ee1efdc37c_512.png',
#    u'image_72': u'https://avatars.slack-edge.com/2016-06-04/48244260161_48ecee52f8ee1efdc37c_72.png',
#    u'image_original': u'https://avatars.slack-edge.com/2016-06-04/48244260161_48ecee52f8ee1efdc37c_original.png',
#    u'real_name': u'',
#    u'real_name_normalized': u''},
#   u'real_name': u'',
#   u'status': None,
#   u'team_id': u'T106M6YDP',
#   u'tz': None,
#   u'tz_label': u'Pacific Daylight Time',
#   u'tz_offset': -25200},
#  {u'color': u'684b6c',
#   u'deleted': False,
#   u'id': u'U1E7C1726',
#   u'is_admin': False,
#   u'is_bot': True,
#   u'is_owner': False,
#   u'is_primary_owner': False,
#   u'is_restricted': False,
#   u'is_ultra_restricted': False,
#   u'name': u'testbotto',
#   u'profile': {u'api_app_id': u'',
#    u'avatar_hash': u'3dd854634a4a',
#    u'bot_id': u'B1E7C1718',
#    u'image_1024': u'https://avatars.slack-edge.com/2016-06-04/48239176293_3dd854634a4a49245adc_512.png',
#    u'image_192': u'https://avatars.slack-edge.com/2016-06-04/48239176293_3dd854634a4a49245adc_192.png',
#    u'image_24': u'https://avatars.slack-edge.com/2016-06-04/48239176293_3dd854634a4a49245adc_24.png',
#    u'image_32': u'https://avatars.slack-edge.com/2016-06-04/48239176293_3dd854634a4a49245adc_32.png',
#    u'image_48': u'https://avatars.slack-edge.com/2016-06-04/48239176293_3dd854634a4a49245adc_48.png',
#    u'image_512': u'https://avatars.slack-edge.com/2016-06-04/48239176293_3dd854634a4a49245adc_512.png',
#    u'image_72': u'https://avatars.slack-edge.com/2016-06-04/48239176293_3dd854634a4a49245adc_72.png',
#    u'image_original': u'https://avatars.slack-edge.com/2016-06-04/48239176293_3dd854634a4a49245adc_original.png',
#    u'real_name': u'',
#    u'real_name_normalized': u''},
#   u'real_name': u'',
#   u'status': None,
#   u'team_id': u'T106M6YDP',
#   u'tz': None,
#   u'tz_label': u'Pacific Daylight Time',
#   u'tz_offset': -25200},
#  {u'color': u'4bbe2e',
#   u'deleted': False,
#   u'id': u'U106MCR4Z',
#   u'is_admin': False,
#   u'is_bot': True,
#   u'is_owner': False,
#   u'is_primary_owner': False,
#   u'is_restricted': False,
#   u'is_ultra_restricted': False,
#   u'name': u'yolobot',
#   u'profile': {u'api_app_id': u'',
#    u'avatar_hash': u'6c8f424ea809',
#    u'bot_id': u'B1066AH0U',
#    u'image_1024': u'https://avatars.slack-edge.com/2016-04-12/34225436049_6c8f424ea80952ef212e_512.png',
#    u'image_192': u'https://avatars.slack-edge.com/2016-04-12/34225436049_6c8f424ea80952ef212e_192.png',
#    u'image_24': u'https://avatars.slack-edge.com/2016-04-12/34225436049_6c8f424ea80952ef212e_24.png',
#    u'image_32': u'https://avatars.slack-edge.com/2016-04-12/34225436049_6c8f424ea80952ef212e_32.png',
#    u'image_48': u'https://avatars.slack-edge.com/2016-04-12/34225436049_6c8f424ea80952ef212e_48.png',
#    u'image_512': u'https://avatars.slack-edge.com/2016-04-12/34225436049_6c8f424ea80952ef212e_512.png',
#    u'image_72': u'https://avatars.slack-edge.com/2016-04-12/34225436049_6c8f424ea80952ef212e_72.png',
#    u'image_original': u'https://avatars.slack-edge.com/2016-04-12/34225436049_6c8f424ea80952ef212e_original.png',
#    u'real_name': u'',
#    u'real_name_normalized': u''},
#   u'real_name': u'',
#   u'status': None,
#   u'team_id': u'T106M6YDP',
#   u'tz': None,
#   u'tz_label': u'Pacific Daylight Time',
#   u'tz_offset': -25200},
#  {u'color': u'757575',
#   u'deleted': False,
#   u'id': u'USLACKBOT',
#   u'is_admin': False,
#   u'is_bot': False,
#   u'is_owner': False,
#   u'is_primary_owner': False,
#   u'is_restricted': False,
#   u'is_ultra_restricted': False,
#   u'name': u'slackbot',
#   u'profile': {u'avatar_hash': u'sv1444671949',
#    u'email': None,
#    u'fields': None,
#    u'first_name': u'slackbot',
#    u'image_192': u'https://a.slack-edge.com/66f9/img/slackbot_192.png',
#    u'image_24': u'https://a.slack-edge.com/0180/img/slackbot_24.png',
#    u'image_32': u'https://a.slack-edge.com/2fac/plugins/slackbot/assets/service_32.png',
#    u'image_48': u'https://a.slack-edge.com/2fac/plugins/slackbot/assets/service_48.png',
#    u'image_512': u'https://a.slack-edge.com/7fa9/img/slackbot_512.png',
#    u'image_72': u'https://a.slack-edge.com/0180/img/slackbot_72.png',
#    u'last_name': u'',
#    u'real_name': u'slackbot',
#    u'real_name_normalized': u'slackbot'},
#   u'real_name': u'slackbot',
#   u'status': None,
#   u'team_id': u'T106M6YDP',
#   u'tz': None,
#   u'tz_label': u'Pacific Daylight Time',
#   u'tz_offset': -25200}]

# %%
if not False:
    print 1
# Out:
# 1

# %%
print sc.api_call()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-f2337d1398bd> in <module>()
# ----> 1 U1E6BSAQG
#
# NameError: name 'U1E6BSAQG' is not defined

# %%
im_list = sc.api_call('im.list')

# %%
im_list
# Out:
# {u'ims': [{u'created': 1465114368,
#    u'id': u'D1E822B2L',
#    u'is_im': True,
#    u'is_org_shared': False,
#    u'is_user_deleted': False,
#    u'user': u'USLACKBOT'},
#   {u'created': 1465116998,
#    u'id': u'D1E818DAA',
#    u'is_im': True,
#    u'is_org_shared': False,
#    u'is_user_deleted': False,
#    u'user': u'U0567FNH4'},
#   {u'created': 1465115666,
#    u'id': u'D1E881L9M',
#    u'is_im': True,
#    u'is_org_shared': False,
#    u'is_user_deleted': False,
#    u'user': u'U1CG94LAZ'},
#   {u'created': 1465116998,
#    u'id': u'D1E818D7Y',
#    u'is_im': True,
#    u'is_org_shared': False,
#    u'is_user_deleted': False,
#    u'user': u'U1E64NRF0'}],
#  u'ok': True}

# %%
user_im_id = ''
for im in im_list['ims']:
    if im['user'] == 'U1CG94LAZ':
        user_im_id = im['id']
        
print user_im_id
# Out:
# D1E881L9M

# %%
from slackclient import SlackClient

token = "xoxb-48268747110-YqfOdmsSrt7Fg7ZgAKhS8BEL" #andrewbot
#token = "xoxb-48229673667-O2UeLMKPQLY9ylFhtKMVLPif" #vonalytics
sc = SlackClient(token)

im_list = sc.api_call('im.list')
